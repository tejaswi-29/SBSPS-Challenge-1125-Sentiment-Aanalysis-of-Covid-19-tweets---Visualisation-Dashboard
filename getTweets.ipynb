# %%
import GetOldTweets3 as got
import pandas as pd

# %%
lockdown1=[]
lockdown2=[]
lockdown3=[]
lockdown4=[]
lockdown5=[]

# %% [markdown]
# ### CONVERT THE TWEETS LIST TO CSV AND STORE THEM IN YOUR LOCAL SYSTEM

# %% [markdown]
# # For lockdown 1

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('#lockdownextended').setNear("Mumbai").setLang('en').setUntil("2020-04-30").setEmoji('unicode').setMaxTweets(1000)
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
convert_tolist(tweets,lockdown1)
# Out:
# {0: 'Just another day in Lockdown 😎 #LockdownExtended #coronavirus', 1: '5 KITS MADE AND DISTRIBUTED TO THE POOR AND NEEDY IN COMPOUND CHAWL BANDRA WEST WITH THE DONATED SUPPLY OF RATION AND OUR FUNDS. MORE 7 KITS WILL BE MADE USING THIS RATION SUPPLY. #FEEDDINGTHENEEDY @INSAANIYAT890 #rationkits #helpingothers #COVIDー19 #LockdownExtended ', 2: 'PSA for govt.. If you tank all our businesses ... 40 percent of 0 is 0. #Covid_19 #Lockdown2 #LockdownExtended', 3: 'Corona be like🤦🏻\u200d♂️ #coronavirusinindia #coronavirus #FightAgainstCorona #LockdownExtended #LockdownKeDushman', 4: 'Cooked Meals distribution in South Mumbai by our team yesterday. #Covid_19 #LockdownExtended #CoronaWarriors #CoronaWarriorsIndia', 5: 'Order today e-commerce website for online food delivery at home in your local area in lockdown and earn good income and boost your business sales. WhatsApp today for quotation: 9819210104 .. #IndiaLockDown #lockdownextension #LockdownExtended #RamadanMubarak', 6: 'We are open
# ...

# %% [markdown]
# ## Tweets from #lockdown till 14th april 2020

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('#lockdown').setNear('Mumbai').setLang('en').setUntil('2020-04-14').setMaxTweets(1000).setEmoji('unicode')
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
convert_tolist(tweets,lockdown1)

# %%
lockdown2=convert_tolist(tweets,lockdown2)

# %%
preprocessing(lockdown2)

# %%
lockdown1=convert_todf(lockdown1)

# %%
lockdown1.head()
# Out:
#                                                                                                                                                                                                                                                     lockdown
# 0                                                                                                                                                                                                just another day in lockdown 😎 lockdownextended coronavirus
# 1  5 kits made and distributed to the poor and needy in compound chawl bandra west with the donated supply of ration and our funds. more 7 kits will be made using this ration supply. feeddingtheneedy  rationkits helpingothers covidー19 lockdownextended
# ...

# %% [markdown]
# ## Tweets from #lockdown2 till 3rd may 2020

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('#lockdown2').setLang('en').setUntil('2020-05-03').setMaxTweets(1000).setEmoji('unicode')
tweets = got.manager.TweetManager.getTweets(tweetCriteria)

# %%
lockdown2=convert_tolist(tweets,lockdown2)

# %%
preprocessing(lockdown2)

# %%
lockdown2=convert_todf(lockdown2)

# %%
lockdown2.head()
# Out:
#                                                                                                                                                                                                                                                       lockdown
# 0                              what a cruel irony that the richest temple in the world leaves 1400 employees in the lurch, amidst lockdown2! is this your government's may day gift to the workers  ? secure their jobs and ensure payments as per  directive!
# 1  found these hand sanitizer wipes strewn about at the back a drawer in the bathroom. abandoned, as if they were garbage. a memento from a bygone era. as good as gold today. worth a modest $325 per wipe in the back alleys of russia. covid__19 lockdown2
# ...

# %% [markdown]
# ## For lockdown 3 stream tweets until 17th may 2020

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('#lockdown3').setLang('en').setUntil('2020-05-17').setMaxTweets(1000).setEmoji('unicode')
tweets = got.manager.TweetManager.getTweets(tweetCriteria)

# %%
lockdown3=convert_tolist(tweets,lockdown3)

# %%
preprocessing(lockdown3)

# %%
lockdown3=convert_todf(lockdown3)

# %%
lockdown3.head()
# Out:
#                                                                                                                                                                                                                                                                                         lockdown
# 0              three old beggar friends (1 hindu &amp; 2 muslims) 500+ kms of the 1600 kms from mumbai to faizabad under lockdown3. they say, "happy to have the company of each other, even in distress." india is going around with hindu-muslim frenzy covid communalvirus migrantlivesmatter
# 1                                                                                                                                         𝐃𝐚𝐲53 of lockdown54 ~ there are far, far better things ahead than any we leave behind. stayhomeindia staysafe lockdown3 lockdownextended lockdownindia
# ...

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('lockdown4.0').setLang('en').setUntil('2020-05-31').setMaxTweets(1000).setEmoji('unicode')
tweets = got.manager.TweetManager.getTweets(tweetCriteria)

# %%
lockdown4=convert_tolist(tweets,lockdown4)

# %%
preprocessing(lockdown4)

# %%
lockdown4=convert_todf(lockdown4)

# %%
lockdown4
# Out:
#                                                                                                                                                                                                                                                                                              lockdown
# 0                                                           we are developing an app for people to get information about bed availability in hospitals: delhicm arvind kejriwal. URL sakal sakaltimes sakalnews viral news viralnews covid19pandemic lockdown4 coronavirusindia health technologynews
# 1                                                           we are developing an app for people to get information about bed availability in hospitals: delhicm arvind kejriwal. URL sakal sakaltimes sakalnews viral news viralnews covid19pandemic lockdown4 coronavirusindia health technologynews
# ...

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('#lockdown5').setLang('en').setUntil('2020-06-09').setMaxTweets(1000).setEmoji('unicode')
tweets = got.manager.TweetManager.getTweets(tweetCriteria)

# %%
lockdown5 = convert_tolist(tweets,lockdown5)

# %%
preprocessing(lockdown5)

# %%
lockdown5 = convert_todf(lockdown5)

# %%
lockdown5
# Out:
#                                                                                                                                                                                                                                                                                  lockdown
# 0                                                                                                                                                            today stream was good thank you to everyone who turned up warzone callofduty lockdown5 staysafe multiplayer duos recruitment
# 1                                                                    URL . walkaway walkwithus virtualwalk virtualtravel don't worry those of you who are highriskcovid19 this lockdown5 will soon be over and i'm hoping to start a project of visitation for housebound patients soon x
# ...

# %%
def convert_tolist(tweets,l):
    for i in tweets:
        l.append(i.text)
    return l
#     preprocessing(l)

# %%
def preprocessing(l):
    for i in range(len(l)):
        l[i]=l[i].lower()
        l[i]=re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',l[i]) #remove URL's
        l[i] = re.sub('@[^\s]+', '', l[i]) # remove usernames
        l[i] = re.sub(r'#([^\s]+)', r'\1', l[i]) # remove the # in #hashtag
#     convert_todf(l)

# %%
import re
words = words.lower()
words = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',words)
words = re.sub(r'#([^\s]+)', r'\1', words)
print(words)
# Out:
# hello there was a a party at her house URL stayhomeee !!!!!

# %%
if "document_tone" in jsonParse.keys():
    if jsonParse["document_tone"]["tones"]!=[]:
        length = len(jsonParse["document_tone"]["tones"])
        k = jsonParse["document_tone"]['tones']
        for i in range(length):
        n = k[i]['tone_name']
        if n in emotions_score:
            emotions_score[n] = emotions_score[n]+k[0]['score']
        else:
            emotions_score.update({n:k[0]['score']})     
        else:
                    continue
            else:
                continue

# %%
import pandas as pd
def convert_todf(l):
    pd.set_option('display.max_colwidth',1000)
    l = pd.DataFrame(l,columns=['lockdown'])
    return l
#     return l
#     convert_tocsv(lockdown)

# %%
df.rename(columns={1:'lockdown1'},inplace=True)

# %%
def convert_tocsv():
    lockdown1.to_csv(r'lockdowntweets.csv',index=False)

# %%
lockdown5.to_csv(r'lockdown5.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2a4c3e6fb1a2> in <module>
# ----> 1 lockdown5.to_csv(r'lockdown5.csv',index=False)
#
# NameError: name 'lockdown5' is not defined
